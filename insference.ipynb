# %%
import cv2

# %%
from ultralytics import YOLO

# %%
model = YOLO("runs/detect/train/weights/best.pt")

# %%
import os
from os import listdir
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img_path = r'dataset\images\val'

classes = ['Саша']
for image_name in os.listdir(img_path):

    full_path = os.path.join(img_path, image_name)
    image = mpimg.imread(full_path)

    results = model(image)
    for result in results:
        # Получаем боксы из результата
        boxes = result.boxes

        for box in boxes:
            x1,y1,x2,y2 = map(int, box.xyxy[0])
            conf = box.conf[0]
            cls = int(box.cls[0])

            label = classes[cls]
            image_cv = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
            cv2.rectangle(image_cv, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(image_cv, label, (x1, y1-10), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
            # Конвертируем обратно для matplotlib
            image = cv2.cvtColor(image_cv, cv2.COLOR_BGR2RGB)

    # Отображаем результат
    plt.figure(figsize=(8, 4))
    plt.imshow(image)
    plt.title(f"Image: {image_name}")
    plt.axis('off')
    plt.show()

# %%
# Захват видео с веб-камеры
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Не удалось открыть камеру")
    exit()

cap.set(cv2.CAP_PROP_FRAME_WIDTH, 720)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Прогоняем кадр через модель
    results = model(frame)[0]  # берем первый результат

    # Рисуем результаты на кадре
    for box in results.boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        conf = box.conf[0]  # confidence
        cls = int(box.cls[0])  # индекс класса

        # Подпись с названием класса и confidence
        label = f"Sasha {conf:.2f}"
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(frame, label, (x1, y1-10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

    # Показ кадра
    cv2.imshow("Webcam YOLOv8", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 Sasha, 307.0ms
# Speed: 43.4ms preprocess, 307.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 298.2ms
# Speed: 2.8ms preprocess, 298.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 298.7ms
# Speed: 1.0ms preprocess, 298.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 330.7ms
# Speed: 1.8ms preprocess, 330.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 311.3ms
# Speed: 1.9ms preprocess, 311.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 281.3ms
# Speed: 1.6ms preprocess, 281.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 304.2ms
# Speed: 1.6ms preprocess, 304.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 282.2ms
# Speed: 1.4ms preprocess, 282.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 286.3ms
# Speed: 1.4ms preprocess, 286.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 283.3ms
# Speed: 1.6ms preprocess, 283.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 292.5ms
# Speed: 1.5ms preprocess, 292.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 405.2ms
# Speed: 1.7ms preprocess, 405.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 376.8ms
# Speed: 2.0ms preprocess, 376.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 308.9ms
# Speed: 2.9ms preprocess, 308.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 290.4ms
# Speed: 1.8ms preprocess, 290.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 291.1ms
# Speed: 1.7ms preprocess, 291.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 288.9ms
# Speed: 1.2ms preprocess, 288.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 310.0ms
# Speed: 2.3ms preprocess, 310.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 280.2ms
# Speed: 1.4ms preprocess, 280.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 279.4ms
# Speed: 1.4ms preprocess, 279.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 265.9ms
# Speed: 1.6ms preprocess, 265.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Sashas, 271.9ms
# Speed: 1.5ms preprocess, 271.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 278.6ms
# Speed: 1.2ms preprocess, 278.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 272.5ms
# Speed: 1.4ms preprocess, 272.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 300.9ms
# Speed: 1.6ms preprocess, 300.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 264.6ms
# Speed: 1.5ms preprocess, 264.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 267.6ms
# Speed: 1.6ms preprocess, 267.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 267.6ms
# Speed: 1.2ms preprocess, 267.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 273.3ms
# Speed: 1.3ms preprocess, 273.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 273.1ms
# Speed: 1.1ms preprocess, 273.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 273.2ms
# Speed: 1.5ms preprocess, 273.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 266.0ms
# Speed: 1.2ms preprocess, 266.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 268.0ms
# Speed: 1.3ms preprocess, 268.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 281.0ms
# Speed: 1.5ms preprocess, 281.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 273.0ms
# Speed: 1.2ms preprocess, 273.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 270.2ms
# Speed: 1.9ms preprocess, 270.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 262.0ms
# Speed: 1.5ms preprocess, 262.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 273.5ms
# Speed: 1.0ms preprocess, 273.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 319.0ms
# Speed: 2.7ms preprocess, 319.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 271.9ms
# Speed: 1.2ms preprocess, 271.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 263.8ms
# Speed: 1.2ms preprocess, 263.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 273.3ms
# Speed: 1.4ms preprocess, 273.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 275.6ms
# Speed: 1.7ms preprocess, 275.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 265.8ms
# Speed: 1.2ms preprocess, 265.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 256.5ms
# Speed: 1.4ms preprocess, 256.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 264.0ms
# Speed: 1.4ms preprocess, 264.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 262.8ms
# Speed: 1.1ms preprocess, 262.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 262.1ms
# Speed: 1.3ms preprocess, 262.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 262.6ms
# Speed: 1.4ms preprocess, 262.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 268.9ms
# Speed: 1.4ms preprocess, 268.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 274.7ms
# Speed: 1.4ms preprocess, 274.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 267.2ms
# Speed: 1.2ms preprocess, 267.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 266.8ms
# Speed: 1.7ms preprocess, 266.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 279.3ms
# Speed: 1.0ms preprocess, 279.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 267.4ms
# Speed: 1.6ms preprocess, 267.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 262.8ms
# Speed: 1.3ms preprocess, 262.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 261.4ms
# Speed: 1.2ms preprocess, 261.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 276.2ms
# Speed: 1.7ms preprocess, 276.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 272.3ms
# Speed: 1.0ms preprocess, 272.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 265.7ms
# Speed: 1.7ms preprocess, 265.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 260.3ms
# Speed: 1.6ms preprocess, 260.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 261.9ms
# Speed: 1.1ms preprocess, 261.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 265.1ms
# Speed: 1.3ms preprocess, 265.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 254.5ms
# Speed: 1.5ms preprocess, 254.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 261.5ms
# Speed: 1.1ms preprocess, 261.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 262.2ms
# Speed: 1.1ms preprocess, 262.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 257.1ms
# Speed: 1.3ms preprocess, 257.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 267.5ms
# Speed: 1.3ms preprocess, 267.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 291.0ms
# Speed: 1.4ms preprocess, 291.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 267.1ms
# Speed: 1.4ms preprocess, 267.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 260.7ms
# Speed: 1.2ms preprocess, 260.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 265.4ms
# Speed: 1.4ms preprocess, 265.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 260.1ms
# Speed: 1.3ms preprocess, 260.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 260.0ms
# Speed: 1.6ms preprocess, 260.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 265.7ms
# Speed: 1.7ms preprocess, 265.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 286.7ms
# Speed: 1.0ms preprocess, 286.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 376.1ms
# Speed: 1.4ms preprocess, 376.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 329.4ms
# Speed: 1.3ms preprocess, 329.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 289.8ms
# Speed: 2.8ms preprocess, 289.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 274.8ms
# Speed: 1.3ms preprocess, 274.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 271.1ms
# Speed: 1.3ms preprocess, 271.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 273.6ms
# Speed: 1.2ms preprocess, 273.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 273.2ms
# Speed: 1.4ms preprocess, 273.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 267.8ms
# Speed: 1.4ms preprocess, 267.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 259.6ms
# Speed: 1.5ms preprocess, 259.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 288.8ms
# Speed: 1.4ms preprocess, 288.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 270.7ms
# Speed: 2.1ms preprocess, 270.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 266.9ms
# Speed: 1.2ms preprocess, 266.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 262.7ms
# Speed: 1.3ms preprocess, 262.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 278.4ms
# Speed: 2.1ms preprocess, 278.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 276.1ms
# Speed: 1.2ms preprocess, 276.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 270.9ms
# Speed: 1.4ms preprocess, 270.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 273.7ms
# Speed: 1.2ms preprocess, 273.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 286.4ms
# Speed: 1.1ms preprocess, 286.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 274.7ms
# Speed: 1.1ms preprocess, 274.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 261.2ms
# Speed: 1.4ms preprocess, 261.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 263.5ms
# Speed: 1.3ms preprocess, 263.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 274.0ms
# Speed: 1.7ms preprocess, 274.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 274.0ms
# Speed: 1.7ms preprocess, 274.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 267.4ms
# Speed: 1.5ms preprocess, 267.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 263.5ms
# Speed: 33.1ms preprocess, 263.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 272.1ms
# Speed: 1.3ms preprocess, 272.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 262.6ms
# Speed: 1.0ms preprocess, 262.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 269.4ms
# Speed: 1.4ms preprocess, 269.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 256.1ms
# Speed: 1.2ms preprocess, 256.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 258.5ms
# Speed: 1.6ms preprocess, 258.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 263.7ms
# Speed: 1.4ms preprocess, 263.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 254.4ms
# Speed: 1.5ms preprocess, 254.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Sashas, 257.7ms
# Speed: 1.6ms preprocess, 257.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 262.5ms
# Speed: 0.9ms preprocess, 262.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 266.5ms
# Speed: 1.1ms preprocess, 266.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 267.4ms
# Speed: 1.2ms preprocess, 267.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 272.0ms
# Speed: 1.4ms preprocess, 272.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 269.3ms
# Speed: 0.9ms preprocess, 269.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 263.9ms
# Speed: 1.3ms preprocess, 263.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 268.9ms
# Speed: 1.2ms preprocess, 268.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 268.9ms
# Speed: 1.2ms preprocess, 268.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 261.1ms
# Speed: 1.2ms preprocess, 261.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sasha, 268.0ms
# Speed: 1.4ms preprocess, 268.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
